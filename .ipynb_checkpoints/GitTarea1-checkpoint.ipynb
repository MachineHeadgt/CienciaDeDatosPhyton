# %% [markdown]
# Version Control GIT
#
# Version control is an usefull tool that helps several peopole to work on one project avoiding the common issues of doing so it gets a team organized and keeps a clean work.
#
# In development some of this issues are.
#
#     - code loss
#     - code overwrite
#     - have an outdated code
#     - unable to work serverla changes at the same time
#     - untrakable changes
#
# there are serveral version cotrol tools can be use now like
#
#     GIT
#     SVN
#     TFS
#     SafeSource
#
# In this class we checked on GIT that is an Open source tool that is currenlty used a lot by software developers teams, I just started to work with GIT on my work integrated to sharepoint and GITFLow for Visual studio and I think is great and better than TFS, I believe is easier to work with, how it manages the code and the way of handeling the branches is better.
#
# I believe GIT is better with an interface because it works thru command lines than can be complicated to momerize some of this GIT inteface are
#
#     GITHub
#     GITFlow
#     GITLab
#     SharePoint
#
#
# the cicle that we do at work is follow.
#
#     -Create a featurebranch from Production repository.
#     -Modify and do all work
#     -commit feature branch to STG repository
#     -Do all QA
#     -Commit feature brach to Production
#     -Deploy
#
# looking at the class the way to go work thru the console it gets kind of complicated and seesm not follow above cicle I didin't see anything about feature branches. it works more on directs commits and branches to the files that is probably because more of the work class in a local repository an its not working on a remote one.
#
#
# Git is very usefull, help us to mantain a clean code without any lost of the code and keeps co workers oganized. you can track anyones changes and keep control of code is hard to manage thru console but it gets easy with a interface.
#
#
# Bellow you can find some examples that I work to git with github and upload this file.

# %%
# %system dir #magic cell just to try
# Out:
# [' Volume in drive C is Windows',
#  ' Volume Serial Number is 00C1-AED2',
#  '',
#  ' Directory of C:\\Users\\JoseA\\Documents\\U\\Python\\PGit\\CienciaDeDatosPhyton',
#  '',
#  '02/18/2020  11:55 PM    <DIR>          .',
#  '02/18/2020  11:55 PM    <DIR>          ..',
#  '02/18/2020  11:45 PM    <DIR>          .ipynb_checkpoints',
#  '02/18/2020  11:55 PM             2,724 GitTarea1.ipynb',
#  '02/18/2020  11:44 PM                81 README.md',
#  '               2 File(s)          2,805 bytes',
#  '               3 Dir(s)  125,503,533,056 bytes free']

# %% [markdown]
# 1.first I create an account on github
#
# 2.Create a repository and upload GiTarea1.ipny with some data
#
#
# 3.enter shell and do following
#
#
#
#
# Microsoft Windows [Version 10.0.18362.657]                                                                              (c) 2019 Microsoft Corporation. All rights reserved.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  C:\Users>cd joseA                                                                                                                                                                                                                               C:\Users\JoseA>cd documents
#
# C:\Users\JoseA\Documents>cd U
#
# C:\Users\JoseA\Documents\U>cd python
#
# C:\Users\JoseA\Documents\U\Python>git init PGit
# Initialized empty Git repository in C:/Users/JoseA/Documents/U/Python/PGit/.git/                                                                                                                                                                                                                                                                                   C:\Users\JoseA\Documents\U\Python>cd PGit
#
# C:\Users\JoseA\Documents\U\Python\PGit>git remote add origin https://github.com/MachineHeadgt/CienciaDeDatosPhyton.git
#
# C:\Users\JoseA\Documents\U\Python\PGit>git remote -v
# origin  https://github.com/MachineHeadgt/CienciaDeDatosPhyton.git (fetch)
# origin  https://github.com/MachineHeadgt/CienciaDeDatosPhyton.git (push)
#
# C:\Users\JoseA\Documents\U\Python\PGit>git clone https://github.com/MachineHeadgt/CienciaDeDatosPhyton.git
# Cloning into 'CienciaDeDatosPhyton'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), 2.30 KiB | 39.00 KiB/s, done.
#     DO some changes in GitTare1.pynb
#
#
#
# C:\Users\JoseA\Documents\U\Python\PGit\CienciaDeDatosPhyton>git add *
# warning: LF will be replaced by CRLF in GitTarea1.ipynb.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .ipynb_checkpoints/GitTarea1-checkpoint.ipynb.
# The file will have its original line endings in your working directory
#
# C:\Users\JoseA\Documents\U\Python\PGit\CienciaDeDatosPhyton>git config user.name joseBenavides
#
# C:\Users\JoseA\Documents\U\Python\PGit\CienciaDeDatosPhyton>git config user.email chepebeanavides@gmail.com
#
# C:\Users\JoseA\Documents\U\Python\PGit\CienciaDeDatosPhyton>git commit
# [master 4e83268] add magic cell
# 2 files changed, 153 insertions(+)
# create mode 100644 .ipynb_checkpoints/GitTarea1-checkpoint.ipynb
#
#
#
# C:\Users\JoseA\Documents\U\Python\PGit\CienciaDeDatosPhyton>git push origin master
#
#
# Total 4 (delta 0), reused 0 (delta 0)
# To https://github.com/MachineHeadgt/CienciaDeDatosPhyton.git
# e27c806..4e83268  master -> master
